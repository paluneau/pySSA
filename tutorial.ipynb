# %%
import numpy as np
from pyssa import mean_speedup_test, median_speedup_test

# %% [markdown]
# Runtimes for multiple runs of a program and an optimized/parallel version of the program (with the same inputs).

# %%
time_opt = np.array([169.3753, 169.6625, 171.9375, 168.6857, 168.9453, 168.7553, 169.7017, 169.5412, 170.65, 170.565, 169.7178, 169.1441, 168.8487, 169.3919, 169.8261, 172.0332, 171.4948, 168.5301, 169.2637, 168.4462, 168.5344, 172.5708, 168.4163, 169.133, 169.5457, 169.9255, 168.6192, 173.1756, 169.1389, 168.4559])
time_ref = np.array([207.8051, 202.0107, 207.6349, 214.3037, 197.5252, 206.8024, 201.727, 202.2293, 204.8753, 203.3792, 201.677, 203.375, 202.5443, 205.3028, 198.9265, 200.7915, 201.4769, 201.8592, 201.9685, 203.2404, 202.7329, 208.476, 200.9186, 202.4549, 208.4984, 204.9497, 207.8669, 202.9414, 214.0824, 201.7764])

# %% [markdown]
# Compute speedups with mean/median and make a statistical significance analysis.

# %%
mean_speedup_test(time_ref, time_opt, 0.05)
# Out:
# Speedup is statistically significant with confidence level 95.0% (p-val. = 1.5310420827050912e-33).
# Reported Speedup = 16.853288679535684%
# /home/mefpp_pluneau/pySSA/pyssa.py:19: UserWarning: Samples are not normally distributed (ref. p-val.=0.015447644215927446, opt. p-val.=0.009793730272071774, risk level=0.05). The confidence level (95.0%) might be incorrect.
#   warn(f"Samples are not normally distributed (ref. p-val.={test_normal_ref.pvalue}, opt. p-val.={test_normal_opt.pvalue}, risk level={alpha}). The confidence level ({conf_lvl}%) might be incorrect.")
# (0.16853288679535683, True)

# %%
median_speedup_test(time_ref, time_opt, 0.05)
# Out:
# Speedup is statistically significant with confidence level 95.0% (p-val. = 1.5099296795810785e-11).
# Reported speedup = 16.49281209088178%
# (0.1649281209088178, True)
